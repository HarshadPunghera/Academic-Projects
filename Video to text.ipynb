# %%
import numpy as np
import cv2

cap = cv2.VideoCapture('Audio test.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import moviepy.editor as mp
clip = mp.VideoFileClip("Audio test.mp4").subclip(0,300)
clip.audio.write_audiofile("theaudio.wav")
# Out:
# MoviePy - Writing audio in theaudio.wav
# MoviePy - Done.

# %%
pip install moviepy
# Out:
# Collecting moviepy
# Requirement already satisfied: numpy>=1.17.3; python_version != "2.7" in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (1.19.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (4.32.1)
# Requirement already satisfied: imageio<3.0,>=2.5; python_version >= "3.4" in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (2.5.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (2.22.0)
# Collecting imageio-ffmpeg>=0.2.0; python_version >= "3.4" (from moviepy)
#   Using cached https://files.pythonhosted.org/packages/ec/5e/58ed5dcf183d4121664b147cab768b74bc5cdc4ea2765905cd2f86e1fde9/imageio_ffmpeg-0.4.2-py3-none-win_amd64.whl
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (4.4.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from moviepy) (0.1.9)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.0.4)
# Installing collected packages: imageio-ffmpeg, moviepy
# Successfully installed imageio-ffmpeg-0.4.2 moviepy-1.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install simpleaudio
# Out:
# Collecting simpleaudio
#   Downloading https://files.pythonhosted.org/packages/c4/7b/a802613a1c2f8558931325711270cffc220e35cefe4060d8e4ef7cfc552a/simpleaudio-1.0.4-cp37-cp37m-win_amd64.whl (2.0MB)
# Installing collected packages: simpleaudio
# Successfully installed simpleaudio-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import simpleaudio as sa

# %%
wave_obj = sa.WaveObject.from_wave_file('theaudio.wav')

# %%
play_obj = wave_obj.play()

# %%
sa.stop_all()

# %%
import simpleaudio as sa

wave_obj = sa.WaveObject.from_wave_file("theaudio.wav")
play_obj = wave_obj.play()
#play_obj.wait_done() #blocking call
while True:
    if(play_obj.is_playing()):
        print('Playing')
    else:
        print('Ended')
        break
# Out:
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# ...
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# PlayingPlaying
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing
# Playing

# %%
# importing libraries 
import speech_recognition as sr 
  
import os 
  
from pydub import AudioSegment 
from pydub.silence import split_on_silence 
  
# a function that splits the audio file into chunks 
# and applies speech recognition 
def silence_based_conversion(path = "alice-medium.wav"): 
  
    # open the audio file stored in 
    # the local system as a wav file. 
    song = AudioSegment.from_wav(path) 
  
    # open a file where we will concatenate   
    # and store the recognized text 
    fh = open("recognized.txt", "w+") 
          
    # split track where silence is 0.5 seconds  
    # or more and get chunks 
    chunks = split_on_silence(song, 
        # must be silent for at least 0.5 seconds 
        # or 500 ms. adjust this value based on user 
        # requirement. if the speaker stays silent for  
        # longer, increase this value. else, decrease it. 
        min_silence_len = 500, 
  
        # consider it silent if quieter than -16 dBFS 
        # adjust this per requirement 
        silence_thresh =song.dBFS-14,
    ) 
  
    # create a directory to store the audio chunks. 
    try: 
        os.mkdir('audio_chunks') 
    except(FileExistsError): 
        pass
  
    # move into the directory to 
    # store the audio files. 
    os.chdir('audio_chunks') 
  
    i = 0
    # process each chunk 
    for chunk in chunks: 
              
        # Create 0.5 seconds silence chunk 
        chunk_silent = AudioSegment.silent(duration = 500) 
  
        # add 0.5 sec silence to beginning and  
        # end of audio chunk. This is done so that 
        # it doesn't seem abruptly sliced. 
        audio_chunk = chunk_silent + chunk + chunk_silent 
  
        # export audio chunk and save it in  
        # the current directory. 
        print("saving chunk{0}.wav".format(i)) 
        # specify the bitrate to be 192 k 
        audio_chunk.export("./chunk{0}.wav".format(i), bitrate ='192k', format ="wav") 
  
        # the name of the newly created chunk 
        filename = 'chunk'+str(i)+'.wav'
  
        print("Processing chunk "+str(i)) 
  
        # get the name of the newly created chunk 
        # in the AUDIO_FILE variable for later use. 
        file = filename 
  
        # create a speech recognition object 
        r = sr.Recognizer() 
  
        # recognize the chunk 
        with sr.AudioFile(file) as source: 
            # remove this if it is not working 
            # correctly. 
            r.adjust_for_ambient_noise(source) 
            audio_listened = r.listen(source) 
  
        try: 
            # try converting it to text 
            rec = r.recognize_google(audio_listened) 
            # write the output to the file. 
            fh.write(rec+". ") 
  
        # catch any errors. 
        except sr.UnknownValueError: 
            print("Could not understand audio") 
  
        except sr.RequestError as e: 
            print("Could not request results. check your internet connection") 
  
        i += 1
  
    os.chdir('..') 
  
  
if __name__ == '__main__': 
          
    print('Enter the audio file path') 
  
    path = input() 
  
    silence_based_conversion(path)
# Out:
# Enter the audio file path
# theaudio.wav
# saving chunk0.wav
# Processing chunk 0
# Could not understand audio
# saving chunk1.wav
# Processing chunk 1
# Could not understand audio
# saving chunk2.wav
# Processing chunk 2
# Could not understand audio
# saving chunk3.wav
# Processing chunk 3
# Could not understand audio
# saving chunk4.wav
# Processing chunk 4
# Could not understand audio
# saving chunk5.wav
# Processing chunk 5
# Could not understand audio
# saving chunk6.wav
# Processing chunk 6
# Could not understand audio
# saving chunk7.wav
# Processing chunk 7
# Could not understand audio
# saving chunk8.wav
# Processing chunk 8
# Could not understand audio
# saving chunk9.wav
# Processing chunk 9
# Could not understand audio
# saving chunk10.wav
# Processing chunk 10
# Could not understand audio
# saving chunk11.wav
# Processing chunk 11
# Could not understand audio
# saving chunk12.wav
# Processing chunk 12
# Could not understand audio
# saving chunk13.wav
# Processing chunk 13
# Could not understand audio
# saving chunk14.wav
# Processing chunk 14
# saving chunk15.wav
# Processing chunk 15
# Could not understand audio
# saving chunk16.wav
# Processing chunk 16
# Could not understand audio
# saving chunk17.wav
# Processing chunk 17
# Could not understand audio
# saving chunk18.wav
# Processing chunk 18
# Could not understand audio
# saving chunk19.wav
# Processing chunk 19
# Could not understand audio
# saving chunk20.wav
# Processing chunk 20
# Could not understand audio
# saving chunk21.wav
# Processing chunk 21
# Could not understand audio
# saving chunk22.wav
# Processing chunk 22
# Could not understand audio
# saving chunk23.wav
# Processing chunk 23
# saving chunk24.wav
# Processing chunk 24
# Could not understand audio
# saving chunk25.wav
# Processing chunk 25
# Could not understand audio
# saving chunk26.wav
# Processing chunk 26
# Could not understand audio
# saving chunk27.wav
# Processing chunk 27
# Could not understand audio
# saving chunk28.wav
# Processing chunk 28
# saving chunk29.wav
# Processing chunk 29
# Could not understand audio
# saving chunk30.wav
# Processing chunk 30
# Could not understand audio
# saving chunk31.wav
# Processing chunk 31
# saving chunk32.wav
# Processing chunk 32
# Could not understand audio
# saving chunk33.wav
# Processing chunk 33
# Could not understand audio
# saving chunk34.wav
# Processing chunk 34
# saving chunk35.wav
# Processing chunk 35
# saving chunk36.wav
# Processing chunk 36
# saving chunk37.wav
# Processing chunk 37
# Could not understand audio
# saving chunk38.wav
# Processing chunk 38
# Could not understand audio
# saving chunk39.wav
# Processing chunk 39
# saving chunk40.wav
# Processing chunk 40
# saving chunk41.wav
# Processing chunk 41
# Could not understand audio
# saving chunk42.wav
# Processing chunk 42
# Could not understand audio
# saving chunk43.wav
# Processing chunk 43
# Could not understand audio
# saving chunk44.wav
# Processing chunk 44
# saving chunk45.wav
# Processing chunk 45
# saving chunk46.wav
# Processing chunk 46
# saving chunk47.wav
# Processing chunk 47
# Could not understand audio
# saving chunk48.wav
# Processing chunk 48
# Could not understand audio
# saving chunk49.wav
# Processing chunk 49
# saving chunk50.wav
# Processing chunk 50
# Could not understand audio
# saving chunk51.wav
# Processing chunk 51
# saving chunk52.wav
# Processing chunk 52
# saving chunk53.wav
# Processing chunk 53
# saving chunk54.wav
# Processing chunk 54
# Could not understand audio
# saving chunk55.wav
# Processing chunk 55
# Could not understand audio
# saving chunk56.wav
# Processing chunk 56
# saving chunk57.wav
# Processing chunk 57
# Could not understand audio
# saving chunk58.wav
# Processing chunk 58
# Could not understand audio
# saving chunk59.wav
# Processing chunk 59
# Could not understand audio
# saving chunk60.wav
# Processing chunk 60
# Could not understand audio
# saving chunk61.wav
# Processing chunk 61
# Could not understand audio
# saving chunk62.wav
# Processing chunk 62
# Could not understand audio
# saving chunk63.wav
# Processing chunk 63
# Could not understand audio
# saving chunk64.wav
# Processing chunk 64
# Could not understand audio
# saving chunk65.wav
# Processing chunk 65
# Could not understand audio
# saving chunk66.wav
# Processing chunk 66
# Could not understand audio
# saving chunk67.wav
# Processing chunk 67
# Could not understand audio
# saving chunk68.wav
# Processing chunk 68
# Could not understand audio
# saving chunk69.wav
# Processing chunk 69
# Could not understand audio
# saving chunk70.wav
# Processing chunk 70
# Could not understand audio
# saving chunk71.wav
# Processing chunk 71
# Could not understand audio
# saving chunk72.wav
# Processing chunk 72
# Could not understand audio
# saving chunk73.wav
# Processing chunk 73
# Could not understand audio
# saving chunk74.wav
# Processing chunk 74
# Could not understand audio
# saving chunk75.wav
# Processing chunk 75
# saving chunk76.wav
# Processing chunk 76
# Could not understand audio
# saving chunk77.wav
# Processing chunk 77
# Could not understand audio
# saving chunk78.wav
# Processing chunk 78
# Could not understand audio
# saving chunk79.wav
# Processing chunk 79
# Could not understand audio
# saving chunk80.wav
# Processing chunk 80
# Could not understand audio
# saving chunk81.wav
# Processing chunk 81
# saving chunk82.wav
# Processing chunk 82
# Could not understand audio
# saving chunk83.wav
# Processing chunk 83
# Could not understand audio
# saving chunk84.wav
# Processing chunk 84
# Could not understand audio
# saving chunk85.wav
# Processing chunk 85
# Could not understand audio
# saving chunk86.wav
# Processing chunk 86
# Could not understand audio
# saving chunk87.wav
# Processing chunk 87
# Could not understand audio
# saving chunk88.wav
# Processing chunk 88
# Could not understand audio
# saving chunk89.wav
# Processing chunk 89
# Could not understand audio
# saving chunk90.wav
# Processing chunk 90
# Could not understand audio
# saving chunk91.wav
# Processing chunk 91
# Could not understand audio
# saving chunk92.wav
# Processing chunk 92
# Could not understand audio
# saving chunk93.wav
# Processing chunk 93
# saving chunk94.wav
# Processing chunk 94
# Could not understand audio
# saving chunk95.wav
# Processing chunk 95
# Could not understand audio
# saving chunk96.wav
# Processing chunk 96
# Could not understand audio
# saving chunk97.wav
# Processing chunk 97
# Could not understand audio
# saving chunk98.wav
# Processing chunk 98
# Could not understand audio
# saving chunk99.wav
# Processing chunk 99
# saving chunk100.wav
# Processing chunk 100
# Could not understand audio
# saving chunk101.wav
# Processing chunk 101
# Could not understand audio
# saving chunk102.wav
# Processing chunk 102
# saving chunk103.wav
# Processing chunk 103
# Could not understand audio
# saving chunk104.wav
# Processing chunk 104
# saving chunk105.wav
# Processing chunk 105

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
r=sr.Recognizer()
with sr.AudioFile("theaudio.wav") as source:
    audio=r.record(source)
    
try:
    s=r.recognize_google(audio)
    print("Text: "+s)
except Exception as e:
    print("Exception:Cannot Understand "+str(e))
# Out:
# Exception:

# %%
from pydub import AudioSegment
from pydub.playback import play
loop = AudioSegment.from_wav("theaudio.wav")
# Play the result
play(loop)

# %%
length = len(loop)

# %%
length  # in milliseconds
# Out:
# 300000

# %%
# Set fade time
fade_time = int(length * 0.5)
# Fade in and out
faded = loop.fade_in(fade_time).fade_out(fade_time)

# %%
pip install sox
# Out:
# Collecting sox
#   Downloading https://files.pythonhosted.org/packages/60/a0/5bee540554af8376e0313e462629d95bf2f2bc3c8cb60697aa01254e6cf5/sox-1.3.7-py2.py3-none-any.whl
# Installing collected packages: sox
# Successfully installed sox-1.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sox --pre
# Out:
# Requirement already satisfied: sox in c:\users\hp\anaconda3\lib\site-packages (1.3.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
path = "theaudio.wav"
print("\nFull text:", get_large_audio_transcription(path))
# Out:
# Error:
# Error:
# Error:
# Error:
# audio-chunks\chunk5.wav : Having program in cpp.
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks\chunk11.wav : Tu.
# Error:
# audio-chunks\chunk13.wav : When become confused are the.
# audio-chunks\chunk14.wav : Teach yourself of things work the book.
# audio-chunks\chunk15.wav : Motivational speakers for class 6.
# Error:
# audio-chunks\chunk17.wav : We can teach machine.
# Error:
# audio-chunks\chunk19.wav : Surya.
# audio-chunks\chunk20.wav : Is teaching that we provide to machine.
# Error:
# Error:
# audio-chunks\chunk23.wav : Definition.
# audio-chunks\chunk24.wav : Machine learning is the study of computer algorithms.
# Error:
# audio-chunks\chunk26.wav : Automatically.
# audio-chunks\chunk27.wav : Machine learning is used.
# audio-chunks\chunk28.wav : Pass data.
# audio-chunks\chunk29.wav : Handmade products in decisions without.
# audio-chunks\chunk30.wav : Unit of energy.
# audio-chunks\chunk31.wav : But not to worry i will consolidate it.
# audio-chunks\chunk32.wav : Features need to know how it works and where can we apply.
# audio-chunks\chunk33.wav : Why is there a need to teach machine.
# Error:
# audio-chunks\chunk35.wav : Why do we need to study machine learning.
# audio-chunks\chunk36.wav : Statistically 60% of.
# audio-chunks\chunk37.wav : New indian population is.
# audio-chunks\chunk38.wav : Occupy my phone.
# audio-chunks\chunk39.wav : We work.
# audio-chunks\chunk40.wav : Day and night so that we all humans can bring food to dinner table at the end.
# audio-chunks\chunk41.wav : We work on large face when scorching heat.
# Error:
# audio-chunks\chunk43.wav : How can we apply a mail to this property.
# audio-chunks\chunk44.wav : In order to make the life easy we can use technology to build my things which will work continuously without getting tired.
# audio-chunks\chunk45.wav : Under a job easily with less time.
# audio-chunks\chunk46.wav : Weekend program machines in such a way so that machines would learn on its own.
# audio-chunks\chunk47.wav : When to water the crops.
# audio-chunks\chunk48.wav : When to cut the crop.
# audio-chunks\chunk49.wav : Mis how much health will it will be for the farm.
# audio-chunks\chunk50.wav : Let's take an example in business rule.
# audio-chunks\chunk51.wav : Business.
# audio-chunks\chunk52.wav : People always try to maximize the profit or minimise the loss.
# audio-chunks\chunk53.wav : So we can program machines in such a way that by seeing the past.
# audio-chunks\chunk54.wav : We would predict sales for the next month.
# audio-chunks\chunk55.wav : How did.
# audio-chunks\chunk56.wav : My meeting.
# audio-chunks\chunk57.wav : Business strategies based on profit and loss.
# audio-chunks\chunk58.wav : Predicted by committee.
# audio-chunks\chunk59.wav : Machine learning examples in our daily life.
# audio-chunks\chunk60.wav : Following are some examples of email that goes a note.
# audio-chunks\chunk61.wav : 1.
# Error:
# audio-chunks\chunk63.wav : Tu.
# Error:
# audio-chunks\chunk65.wav : Free.
# audio-chunks\chunk66.wav : Fraud detection.
# audio-chunks\chunk67.wav : Ho.
# audio-chunks\chunk68.wav : Movie recommendation.
# Error:
# audio-chunks\chunk70.wav : Vehicle driving system.
# Error:
# Error:
# Error:
# audio-chunks\chunk74.wav : Social network.
# audio-chunks\chunk75.wav : 8.
# audio-chunks\chunk76.wav : Speech recognition and many more.
# audio-chunks\chunk77.wav : Following are the email technique explanation.
# audio-chunks\chunk78.wav : Supervised learning.
# audio-chunks\chunk79.wav : Y equal to a perfect.
# Error:
# Error:
# audio-chunks\chunk82.wav : Input data independent predictor variable.
# audio-chunks\chunk83.wav : Why.
# Error:
# Error:
# audio-chunks\chunk86.wav : Loan.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks\chunk94.wav : Token tax of four letter.
# audio-chunks\chunk95.wav : Dog coming small to large size.
# audio-chunks\chunk96.wav : On the other hand a most.
# audio-chunks\chunk97.wav : Dogs largemouth.
# Error:
# audio-chunks\chunk99.wav : Dogs bark while catch.
# audio-chunks\chunk100.wav : After learning of observing the above point if its i was able to identify.
# audio-chunks\chunk101.wav : Features.
# audio-chunks\chunk102.wav : If not then the movie.
# audio-chunks\chunk103.wav : Which type of learning is called supervised.
# audio-chunks\chunk104.wav : In terms of apple.
# audio-chunks\chunk105.wav : Input raw data.
# audio-chunks\chunk106.wav : When we apply supervised learning algorithms and give an input to the body it stores whether the input is an apple or not.
#
# Full text: Having program in cpp. Tu. When become confused are the. Teach yourself of things work the book. Motivational speakers for class 6. We can teach machine. Surya. Is teaching that we provide to machine. Definition. Machine learning is the study of computer algorithms. Automatically. Machine learning is used. Pass data. Handmade products in decisions without. Unit of energy. But not to worry i will consolidate it. Features need to know how it works and where can we apply. Why is there a need to teach machine. Why do we need to study machine learning. Statistically 60% of. New indian population is. Occupy my phone. We work. Day and night so that we all humans can bring food to dinner table at the end. We work on large face when scorching heat. How can we apply a mail to this property. In order to make the life easy we can use technology to build my things which will work continuously without getting tired. Under a job easily with less time. Weekend program machines in such a way so that machines would learn on its own. When to water the crops. When to cut the crop. Mis how much health will it will be for the farm. Let's take an example in business rule. Business. People always try to maximize the profit or minimise the loss. So we can program machines in such a way that by seeing the past. We would predict sales for the next month. How did. My meeting. Business strategies based on profit and loss. Predicted by committee. Machine learning examples in our daily life. Following are some examples of email that goes a note. 1. Tu. Free. Fraud detection. Ho. Movie recommendation. Vehicle driving system. Social network. 8. Speech recognition and many more. Following are the email technique explanation. Supervised learning. Y equal to a perfect. Input data independent predictor variable. Why. Loan. Token tax of four letter. Dog coming small to large size. On the other hand a most. Dogs largemouth. Dogs bark while catch. After learning of observing the above point if its i was able to identify. Features. If not then the movie. Which type of learning is called supervised. In terms of apple. Input raw data. When we apply supervised learning algorithms and give an input to the body it stores whether the input is an apple or not.

# %%
import cv2
import os

cam = cv2.VideoCapture(0)
cam.set(3, 640) # set video width
cam.set(4, 480) # set video height

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# For each person, enter one numeric face id
face_id = input('\n enter user id end press <return> ==>  ')

print("\n [INFO] Initializing face capture. Look the camera and wait ...")
# Initialize individual sampling face count
count = 0

while(True):
    ret, img = cam.read()
    img = cv2.flip(img, -1) # flip video image vertically
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+w,y+h), (255,0,0), 2)     
        count += 1

        # Save the captured image into the datasets folder
        cv2.imwrite("dataset/User." + str(face_id) + '.' + str(count) + ".jpg", gray[y:y+h,x:x+w])

        cv2.imshow('image', img)

    k = cv2.waitKey(100) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 30: # Take 30 face sample and stop video
         break

# Do a bit of cleanup
print("\n [INFO] Exiting Program and cleanup stuff")
cam.release()
cv2.destroyAllWindows()
# Out:
#  enter user id end press <return> ==>  1
#
#  [INFO] Initializing face capture. Look the camera and wait ...
#
#  [INFO] Exiting Program and cleanup stuff

# %%
import cv2
import numpy as np
from PIL import Image
import os

# Path for face image database
path = 'dataset'

recognizer = cv2.face.LBPHFaceRecognizer_create()
detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml");

# function to get the images and label data
def getImagesAndLabels(path):
    imagePaths = [os.path.join(path,f) for f in os.listdir(path)]     
    faceSamples=[]
    ids = []
    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L') # convert it to grayscale
        img_numpy = np.array(PIL_img,'uint8')
        id = int(os.path.split(imagePath)[-1].split(".")[1])
        faces = detector.detectMultiScale(img_numpy)
        for (x,y,w,h) in faces:
            faceSamples.append(img_numpy[y:y+h,x:x+w])
            ids.append(id)
    return faceSamples,ids

print ("\n [INFO] Training faces. It will take a few seconds. Wait ...")
faces,ids = getImagesAndLabels(path)
recognizer.train(faces, np.array(ids))

# Save the model into trainer/trainer.yml
recognizer.write('trainer/trainer.yml') # recognizer.save() worked on Mac, but not on Pi

# Print the numer of faces trained and end program
print("\n [INFO] {0} faces trained. Exiting Program".format(len(np.unique(ids))))
# Out:
#  [INFO] Training faces. It will take a few seconds. Wait ...
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-5-e7f22bedf48d> in <module>
#      26
#      27 print ("\n [INFO] Training faces. It will take a few seconds. Wait ...")
# ---> 28 faces,ids = getImagesAndLabels(path)
#      29 recognizer.train(faces, np.array(ids))
#      30
#
# <ipython-input-5-e7f22bedf48d> in getImagesAndLabels(path)
#      12 # function to get the images and label data
#      13 def getImagesAndLabels(path):
# ---> 14     imagePaths = [os.path.join(path,f) for f in os.listdir(path)]
#      15     faceSamples=[]
#      16     ids = []
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'C:/Users/HP/ML Face/HP.png'

# %%
pip install opencv-contrib-python --user
# Out:
# Collecting opencv-contrib-python
#   Using cached https://files.pythonhosted.org/packages/c6/a1/d0fd1ea9d5417437e6271e7f88d3ed155f64a979d3ccd926a3b21d4404dd/opencv_contrib_python-4.2.0.34-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: numpy>=1.14.5 in c:\users\hp\anaconda3\lib\site-packages (from opencv-contrib-python) (1.19.0)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.2.0.34
# Note: you may need to restart the kernel to use updated packages.

# %%
#Python 2.x program to transcribe an Audio file 
import speech_recognition as sr 
  
AUDIO_FILE = ("theaudio.wav") 
  
# use the audio file as the audio source 
  
r = sr.Recognizer() 
  
with sr.AudioFile(AUDIO_FILE) as source: 
    #reads the audio file. Here we use record instead of 
    #listen 
    audio = r.record(source)   

try: 
    print("The audio file contains: " + r.recognize_google(audio)) 
    
except sr.UnknownValueError: 
    print("Google Speech Recognition could not understand audio") 
    
except sr.RequestError as e: 
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Google Speech Recognition could not understand audio

# %%
file = open("recognized.txt", "rt") 
data = file.read() 
words = data.split() 
print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 106

# %%
import nltk
from nltk.tokenize import sent_tokenize

sentences = data
number_of_sentences = sent_tokenize(sentences)

print(len(number_of_sentences))
# Out:
# 24

# %%
with open('recognized.txt', 'r') as file1:
    with open('Qpaper.txt', 'r') as file2:
        same = set(file1).intersection(file2)

same.discard('\n')

with open('some_output_file.txt', 'w') as file_out:
    for line in same:
        file_out.write(line)

# %%
from difflib import SequenceMatcher
file1='recognized.txt'
file2='Qpaper.txt'
text1 = open(file1).read()
text2 = open(file2).read()
m = SequenceMatcher(None, text1, text2)
m.ratio()
# Out:
# 0.9348167539267016

# %%
import operator
f1=open('recognized.txt','r') #file 1
f2=open('Qpaper.txt','r') #file 2

wordlist=[]
wordlist2=[]
for line in f1:
    for word in line.split():
        wordlist.append(word)

for line in f2:
    for word in line.split():
        wordlist2.append(word)

worddictionary = {}
for word in wordlist:
    if word in worddictionary:
        worddictionary[word] += 1
    else:
        worddictionary[word] = 1

worddictionary2 = {}
for word in wordlist2:
    if word in worddictionary2:
        worddictionary2[word] += 1
    else:
        worddictionary2[word] = 1

print(worddictionary)
print(worddictionary2)
# Out:
# {'What': 1, 'is': 14, 'Machine': 2, 'Learning': 7, '?': 1, 'Before': 1, 'talking': 1, 'about': 2, 'machines': 8, 'letâ€™s': 1, 'talk': 1, 'how': 3, 'humans': 2, 'learn.': 1, 'Right': 1, 'from': 1, 'the': 21, 'childhood': 1, 'we': 12, 'had': 3, 'been': 3, 'programmed': 2, 'to': 17, 'react,': 1, 'decide,': 1, 'feel': 1, 'in': 12, 'a': 11, 'certain': 3, 'way': 4, 'consciously': 1, 'or': 4, 'subconsciously.': 1, 'How': 4, 'programmed?': 1, 'Answer': 1, 'very': 1, 'simple.': 1, 'We': 3, 'two': 1, 'ways:': 1, '1.Externally:': 1, 'By': 2, 'people,': 1, 'by': 4, 'their': 2, 'behaviour': 1, '&': 1, 'environment': 1, 'where': 1, 'live': 1, '2.': 1, 'Internally': 1, ':': 1, 'When': 4, 'became': 1, 'conscious': 1, 'at': 2, 'age': 1, 'of': 11, '6.': 1, 'teach': 3, 'ourselves': 1, 'things': 1, 'work': 4, 'through': 1, 'books,': 1, 'motivational': 1, 'speakers,podcasts': 1, 'etc.': 2, 'Similarly': 1, 'can': 6, 'behave,': 1, 'react': 1, 'way.': 1, 'This': 1, 'teaching': 1, 'that': 7, 'provide': 1, 'and': 15, 'behaving': 1, 'called': 2, 'machine': 1, 'learning.': 1, 'learning?': 1, 'Statistically': 1, '60%': 1, 'Indian': 1, 'population': 1, 'occupied': 1, 'farmers.': 2, 'They': 2, 'day': 1, 'night': 1, 'so': 2, 'all': 1, 'bring': 1, 'food': 1, 'dinner': 1, 'table': 1, 'end': 1, 'day.': 1, 'on': 4, 'large': 2, 'fields': 1, 'scorching': 1, 'heat': 1, 'continuously.': 1, 'apply': 2, 'ML': 4, 'this': 4, 'problem..?': 1, 'In': 5, 'order': 1, 'make': 1, 'life': 1, 'easy': 1, 'use': 3, 'technology': 1, 'build': 1, 'which': 2, 'continuously': 1, 'without': 1, 'getting': 1, 'tired': 1, 'does': 1, 'our': 2, 'job': 1, 'easily': 1, 'with': 1, 'less': 1, 'time.': 1, 'program': 2, 'such': 2, 'would': 5, 'learn': 1, 'itâ€™s': 1, 'own': 1, 'when': 3, 'water': 1, 'crops,': 1, 'cut': 1, 'crops': 1, 'Imagine': 1, 'much': 1, 'helpful': 1, 'it': 2, 'be': 1, 'for': 2, 'Letâ€™s': 1, 'take': 1, 'an': 2, 'example': 2, 'business': 2, 'domain.': 1, 'Business': 1, 'people': 1, 'always': 1, 'tries': 1, 'maximize': 1, 'profits': 1, 'minimize': 1, 'loss.': 1, 'So,': 1, 'seeing': 1, 'past': 1, 'sales,': 1, 'they': 1, 'predict': 1, 'sales': 1, 'next': 1, 'month.': 1, 'help?': 1, 'making': 1, 'strategies': 1, 'based': 1, 'profit': 1, 'loss': 1, 'predicted': 1, 'machine.': 1, 'examples': 2, 'Daily': 1, 'Lives.': 1, 'Following': 3, 'are': 5, 'some': 3, 'goes': 1, 'unnoticed:': 1, 'Vehicle': 1, 'Driver': 1, 'Assistance': 1, 'Web': 1, 'Advertisements': 1, 'Social': 1, 'Networks': 1, 'Speech': 1, 'Recognition': 1, 'many': 1, 'more': 2, 'techniques': 1, 'explanation:': 1, 'Supervised': 5, 'Y': 3, '=': 1, 'f': 1, '(x)': 1, 'Where,': 1, 'x=Input': 1, 'Data': 3, '(Independent': 1, '/': 6, 'Predictor': 1, 'Variable)': 2, 'Y=Output': 1, '(Dependent': 1, 'Target': 1, 'Learning,': 1, 'model': 1, 'learns': 1, 'using': 1, 'Input': 1, 'Output': 1, 'also': 1, 'known': 1, 'as': 2, 'Labeled': 1, 'Data.': 1, 'Outcome': 1, 'known.': 1, 'For': 2, 'e.g.': 2, 'do': 1, 'you': 1, 'child': 3, 'identify': 2, 'Dog': 1, 'Cat.': 1, 'Here': 1, 'features': 2, 'help': 1, 'us': 1, 'identify.': 1, 'Dogs': 4, 'cats': 3, 'both': 2, 'have': 4, '4': 2, 'legs': 1, 'tail.': 1, 'come': 1, 'small': 1, 'sizes.': 1, 'Cats,': 1, 'other': 1, 'hand,': 1, 'mostly': 1, 'small.': 1, 'long': 1, 'mouth': 1, 'while': 2, 'smaller': 1, 'mouths.': 1, 'bark': 1, 'meow.': 1, 'After': 1, 'learning': 4, 'observing': 1, 'above': 1, 'points': 1, 'if': 2, 'able': 1, 'perfectly': 1, 'animals': 1, 'then': 2, '(': 1, 'labels': 1, ')': 1, 'were': 1, 'good': 1, 'enough': 1, 'not': 1, 'tell': 1, 'your': 1, 'features,': 1, 'type': 2, 'Learning.': 1, 'terms': 2, 'apples': 1, 'input': 3, 'raw': 1, 'data,': 1, 'supervised': 1, 'algorithms': 1, 'giving': 1, 'unseen': 1, 'model,': 1, 'shows': 1, 'whether': 1, 'apple': 1, 'not.': 1, 'There': 1, '2': 1, 'types': 1, 'Techniques': 1, 'named': 1, 'Regression': 1, 'Classification.': 2, '(output': 2, 'Dependent': 2, 'target)': 2, 'Continuous': 2, 'variable,': 2, 'Regression.': 1, 'Discrete': 2, 'Now,': 1, 'wh ...
# {'What': 1, 'is': 17, 'Machine': 4, 'Learning': 8, '?': 1, 'Before': 1, 'talking': 1, 'about': 2, 'machines': 8, 'letâ€™s': 1, 'talk': 1, 'how': 4, 'humans': 2, 'learn.': 1, 'Right': 1, 'from': 1, 'the': 22, 'childhood': 1, 'we': 15, 'had': 3, 'been': 3, 'programmed': 2, 'to': 21, 'react,': 1, 'decide,': 1, 'feel': 1, 'in': 12, 'a': 11, 'certain': 3, 'way': 4, 'consciously': 1, 'or': 4, 'subconsciously.': 1, 'How': 4, 'programmed?': 1, 'Answer': 1, 'very': 1, 'simple.': 1, 'We': 3, 'two': 1, 'ways:': 1, '1.Externally:': 1, 'By': 2, 'people,': 1, 'by': 4, 'their': 2, 'behaviour': 1, '&': 1, 'environment': 1, 'where': 2, 'live': 1, '2.': 1, 'Internally': 1, ':': 1, 'When': 4, 'became': 1, 'conscious': 1, 'at': 2, 'age': 1, 'of': 12, '6.': 1, 'teach': 4, 'ourselves': 1, 'things': 1, 'work': 4, 'through': 2, 'books,': 1, 'motivational': 1, 'speakers,podcasts': 1, 'etc.': 2, 'Similarly': 1, 'can': 7, 'behave,': 1, 'react': 1, 'way.': 1, 'This': 1, 'teaching': 1, 'that': 9, 'provide': 1, 'and': 17, 'behaving': 1, 'called': 2, 'machine': 2, 'learning.': 1, 'Definition:': 1, 'learning': 5, 'study': 2, 'computer': 1, 'algorithms': 3, 'improve': 1, 'automatically': 1, 'experienceâ€¦(Wikipedia)': 1, 'using/making': 1, 'algorithm': 1, 'learns': 2, 'on': 5, 'past': 2, 'data': 1, 'make': 2, 'prediction/decision': 1, 'without': 2, 'human': 1, 'intervention.': 1, 'But': 1, 'not': 2, 'worry': 1, 'are': 6, 'already': 1, 'written,': 1, 'just': 1, 'need': 3, 'know': 1, 'it': 3, 'works': 1, 'apply': 3, 'it.': 1, 'Why': 1, 'there': 1, 'machines?': 1, 'Or': 1, 'why': 1, 'do': 2, 'learning?': 1, 'Statistically': 1, '60%': 1, 'Indian': 1, 'population': 1, 'occupied': 1, 'farmers.': 2, 'They': 2, 'day': 1, 'night': 1, 'so': 2, 'all': 1, 'bring': 1, 'food': 1, 'dinner': 1, 'table': 1, 'end': 1, 'day.': 1, 'large': 2, 'fields': 1, 'scorching': 1, 'heat': 1, 'continuously.': 1, 'ML': 4, 'this': 4, 'problem..?': 1, 'In': 5, 'order': 1, 'life': 1, 'easy': 1, 'use': 3, 'technology': 1, 'build': 1, 'which': 2, 'continuously': 1, 'getting': 1, 'tired': 1, 'does': 1, 'our': 2, 'job': 1, 'easily': 1, 'with': 1, 'less': 1, 'time.': 1, 'program': 2, 'such': 2, 'would': 5, 'learn': 1, 'itâ€™s': 1, 'own': 1, 'when': 3, 'water': 1, 'crops,': 1, 'cut': 1, 'crops': 1, 'Imagine': 1, 'much': 1, 'helpful': 1, 'be': 1, 'for': 2, 'Letâ€™s': 1, 'take': 1, 'an': 2, 'example': 2, 'business': 2, 'domain.': 1, 'Business': 1, 'people': 1, 'always': 1, 'tries': 1, 'maximize': 1, 'profits': 1, 'minimize': 1, 'loss.': 1, 'So,': 1, 'seeing': 1, 'sales,': 1, 'they': 1, 'predict': 1, 'sales': 1, 'next': 1, 'month.': 1, 'help?': 1, 'making': 1, 'strategies': 1, 'based': 1, 'profit': 1, 'loss': 1, 'predicted': 1, 'machine.': 1, 'examples': 2, 'Daily': 1, 'Lives.': 1, 'Following': 3, 'some': 3, 'goes': 1, 'unnoticed:': 1, 'Spam': 1, 'Filtering': 1, 'Web': 2, 'Search': 1, 'Fraud': 1, 'Detection': 1, 'Movie': 1, 'Recommendations': 1, 'Vehicle': 1, 'Driver': 1, 'Assistance': 1, 'Advertisements': 1, 'Social': 1, 'Networks': 1, 'Speech': 1, 'Recognition': 1, 'many': 1, 'more': 2, 'techniques': 1, 'explanation:': 1, 'Supervised': 5, 'Y': 3, '=': 1, 'f': 1, '(x)': 1, 'Where,': 1, 'x=Input': 1, 'Data': 3, '(Independent': 1, '/': 6, 'Predictor': 1, 'Variable)': 2, 'Y=Output': 1, '(Dependent': 1, 'Target': 1, 'Learning,': 1, 'model': 1, 'using': 1, 'Input': 1, 'Output': 1, 'also': 1, 'known': 1, 'as': 2, 'Labeled': 1, 'Data.': 1, 'Outcome': 1, 'known.': 1, 'For': 2, 'e.g.': 2, 'you': 1, 'child': 3, 'identify': 2, 'Dog': 1, 'Cat.': 1, 'Here': 1, 'features': 2, 'help': 1, 'us': 1, 'identify.': 1, 'Dogs': 4, 'cats': 3, 'both': 2, 'have': 4, '4': 2, 'legs': 1, 'tail.': 1, 'come': 1, 'small': 1, 'sizes.': 1, 'Cats,': 1, 'other': 1, 'hand,': 1, 'mostly': 1, 'small.': 1, 'long': 1, 'mouth': 1, 'while': 2, 'smaller': 1, 'mouths.': 1, 'bark': 1, 'meow.': 1, 'After': 1, 'observing': 1, 'above': 1, 'points': 1, 'if': 2, 'able': 1, 'perfectly': 1, 'animals': 1, 'then': 2, '(': 1, 'labels': 1, ')': 1, 'were': 1 ...

# %%
file_list = [f1, f2] # This would hold all your open files
num_files = len(file_list)

frequencies = {} # We'll just make one dictionary to hold the frequencies

for i, f in enumerate(file_list): # Loop over the files, keeping an index i
    for line in f: # Get the lines of that file
        for word in line.split(): # Get the words of that file
            if not word in frequencies:
                frequencies[word] = [0 for _ in range(num_files)] # make a list of 0's for any word you haven't seen yet -- one 0 for each file

            frequencies[word][i] += 1 # Increment the frequency count for that word and file

print(frequencies)
# Out:
# {}
